# %%
import urllib
from bs4 import BeautifulSoup as soup
import numpy as np
import math


ogPage = input("Enter Round 1 pairings URL (w/ https://):")


page = urllib.request.urlopen(ogPage)
tab = soup(page, "html.parser")
numByes = 0
names = []
html = []
speaks = []
cumeSpeaks = 0
byes = 0
data = tab.find_all(class_= "white smallish padtop padbottom padleft")
dataList = list(data)
length = len(dataList)

for x in range(length):
    if not ("," in str(dataList[x].text.strip())):
        names.append(dataList[x].text.strip())
        html.append(dataList[x].get("href"))
#print (names)




prelimPage  = "https://www.tabroom.com" + str(html[0])
page = urllib.request.urlopen(prelimPage)
tab = soup(page, "html.parser")

data = tab.find_all(class_= "tenth semibold")
dataList = list(data)
length = len(dataList)
totalRounds = []
prelimCounter = 0 

for x in range(length):
    totalRounds.append(dataList[x].text.strip())
for x in (range(len(totalRounds))):
    if ("Round" in totalRounds[x]):
        prelimCounter = prelimCounter + 1
rounds = prelimCounter
times = rounds*2
print(rounds)

highLow = [0]*len(names)
wins = [0]*len(names)
for tms in range(len(html)):
    numByes = 0;
    ogPage = "https://www.tabroom.com" + str(html[tms])
    page = urllib.request.urlopen(ogPage)
    tab = soup(page, "html.parser")

    #side or bye
    side = tab.find_all(class_= "tenth")
    sideList = list(side)

    #for x in range(len(sideList)):
#         if (str(sideList[x].text.strip()) == "Bye"):
#             numByes = numByes + 1
            #wins[tms] = wins[tms] + 1
    #round number        
    roundInfo = tab.find_all(class_="tenth semibold")
    roundList = list(roundInfo)
    
    #win or lose
    data = tab.find_all(class_= "tenth centeralign semibold")
    dataList = list(data)
    length = len(dataList)
    
    #opp names
    oppList = list(tab.find_all(class_="white padtop padbottom"))
    if (rounds <= length):
        #print (names[tms] + " " + str(rounds-numByes))
        for x in range(rounds):
            #print (names[tms] + " " + dataList[len(dataList) - 1 - x].text.strip())
            if (dataList[len(dataList) - 1 - x].text.strip() == "W"):
                wins[tms] = wins[tms] + 1
            if (dataList[len(dataList) - 1 - x].text.strip() == ""):
                wins[tms] = wins[tms] + 1
                numByes += 1
    
    
    speaksList = list(tab.find_all(class_="fifth marno"))
    tempList = []
    for x in range(len(speaksList)):
        tempList.append(speaksList[x].text.strip())
    speaks.append(tempList)
    sum1 = 0
    sum2 = 0
    if (len(speaks[tms]) < (rounds*2) and len(speaks[tms]) > 0):
        for y in range(len(speaks[tms])):
            if (y % 2 == 0):
                sum1 = sum1 + float(speaks[tms][y])            
            else:
                sum2 = sum2 + float(speaks[tms][y])
        sum1 = float(sum1 /  ( (len(speaks[tms])) / 2))
        sum1 = float(sum2 /  ( (len(speaks[tms])) / 2))
    for y in range(numByes):
        print(names[tms])
        speaks[tms].append(sum1)
        speaks[tms].append(sum2)
# Out:
# Enter Round 1 pairings URL (w/ https://):https://www.tabroom.com/index/tourn/postings/round.mhtml?tourn_id=12924&round_id=434342
# 7
# Fargo Shanley OG
# Fargo Shanley OG
# McDowell LD
# Dowling Catholic HP
# Cranbrook KL
# Westwood SK
# Brentwood LS
# Phoenix Country Day MS
# James Logan SA
# Green Canyon CP
# Green Canyon CP
# Fairmont Prep GJ
# Oxbridge Academy of the Palm Beaches SC
# NSU RG
# Fargo Shanley WK
# Fargo Shanley WB
# Park City GP
# Ravenwood MM
# Bloomington HS South FB
# Park City AW

# %%
speaker1 = []
speaker2 = []
for x in range(len(speaks)):
    tempList1 = []
    tempList2 = []
    for y in range(len(speaks[x])):
        if (y % 2 == 0):
            tempList1.append(speaks[x][y])
        else:
            tempList2.append(speaks[x][y])
    speaker1.append(tempList1)
    speaker2.append(tempList2)
for x in range(len(speaker1)):
    speaker1[x] = [float(i) for i in speaker1[x]] 
    speaker2[x] = [float(i) for i in speaker2[x]]
for x in range(len(speaker1)):
    if (len(speaker1[x]) > 2):
        speaker1[x].remove(max(speaker1[x]))
        speaker1[x].remove(min(speaker1[x]))
        speaker2[x].remove(min(speaker2[x]))
        speaker2[x].remove(max(speaker2[x]))
total1 = []
total2 = []
totalHL = []
for x in range(len(speaker1)):
    total1.append(sum(speaker1[x]))
    total2.append(sum(speaker2[x]))
for x in range(len(speaker1)):
    totalHL.append(total1[x] + total2[x])
# for x in range(len(names)):
#     print(names[x] + " " + str(wins[x]) + " " + str(speaker1[x]) + " " + str(speaker2[x]) + " " + str(totalHL[x]))

fin = []
for x in reversed(range(rounds+1)):
    temp = []
    for tms in range(len(names)):
        if (wins[tms] == x):
            temp.append(tms) 
    
    dio = {}
    for y in range(len(temp)):
        dio[temp[y]] = totalHL[temp[y]]
    ah = sorted(dio, key=dio.get, reverse=True)
    for p in range(len(ah)):
        fin.append(names[ah[p]])
        #print(names[ah[p]])
for x in range(len(fin)):
    print (str(x+1) + ". " + fin[x])

#finding actual cume speaks 

#https://www.tabroom.com/index/tourn/postings/round.mhtml?tourn_id=15530&round_id=526576
# Out:
# 1. Westlake DL
# 2. Bronx Science OS
# 3. Fairmont Prep BC
# 4. Blake JS
# 5. Westridge BM
# 6. Hunter BX
# 7. Cinco Ranch RT
# 8. Westlake HY
# 9. Park City EP
# 10. Dalton CY
# 11. Edina MZ
# 12. American Heritage Plantation ZR
# 13. Lake Highland Prep KP
# 14. Chagrin Falls HM
# 15. Fairmont Prep GJ
# 16. Edina WJ
# 17. Westwood LR
# 18. Campbell Hall FL
# 19. Delbarton FF
# 20. Westlake PW
# 21. Strake Jesuit  CW
# 22. Seven Lakes RZ
# 23. Campbell Hall LD
# 24. Strake Jesuit  JA
# 25. Ransom Everglades SR
# 26. Fairmont Prep SS
# 27. Delbarton LT
# 28. Hawken GE
# 29. Dulles CL
# 30. Winston Churchill DD
# 31. Edgemont KS
# 32. Lake Highland Prep KS
# 33. Marist SV
# 34. Bronx Science MR
# 35. Cypress Bay CB
# 36. Duchesne Academy of the Sacred Heart DL
# 37. Potomac AA
# 38. Strake Jesuit  GB
# 39. Bronx Science DG
# 40. Durham HD
# 41. Cranbrook RS
# 42. Westwood SK
# 43. Blake HR
# 44. Poly Prep Country Day ML
# 45. Anderson BC
# 46. Fargo Shanley OG
# 47. Durham OK
# 48. Phoenix Country Day OH
# 49. Fairmont Prep SA
# 50. Colleyville Heritage LW
# 51. Brophy  KS
# 52. Charlotte Catholic WC
# 53. Edina NT
# 54. Charlotte Latin NS
# 55. Miami Beach Sr KV
# 56. Edina MM
# 57. Blake PS
# 58. Chanhassen VK
# 59. Colleyville Heritage SL
# 60. Nova RA
# 61. Delbarton GM
# 62. American Heritage Plantation ZaRa
# 63. Blake OP
# 64. Hunter CK
# 65. Quarry Lane SJ
# 66. Archbishop Mitty RS
# 67. William Fremd BK
# 68. Miami Beach Sr MM
# 69. Westlake SY
# 70. Interlake KP
# 71. Nueva WC
# 72. Ransom Everglades GM
# 73. Mountain Brook DK
# 74. Park City AW
# 75. James Bowie GW
# 76. Presentation DP
# 77. Fairmont Prep BR
# 78. Westridge OW
# 79. Anderson FY
# 80. Edgemont MM
# 81. Oakwood School - North Hollywood GM
# 82. Hunter WO
# 83. NSU RF
# 84. William Fremd SW
# 85. Delbarton AG
# 86. National Cathedral AC
# 87. Duchesne Academy of the Sacred Heart BD
# 88. Bethesda Chevy Chase GT
# 89. Flintridge Prep GK
# 90. Ransom Everglades FK
# 91. Blake PW
# 92. Rowland Hall BG
# 93. Ravenwood MM
# 94. Mountain Brook HC
# 95. Strake Jesuit  HT
# 96. Hunter KB
# 97. Fargo Shanley WK
# 98. Green Canyon CP
# 99. Lake Highland Prep CP
# 100. Westlake HG
# 101. Ardrey Kell RS
# 102. Thomas Jefferson HSST GD
# 103. Bronx Science SW
# 104. Dalton SY
# 105. Hawken WG
# 106. Archbishop Mitty KP
# 107. Flintridge Prep CS
# 108. James Logan SA
# 109. Lincoln FG
# 110. Chesterton KW
# 111. Flintridge Prep HN
# 112. Madison West AH
# 113. St Francis BC
# 114. Cypress Bay BK
# 115. Lake Highland Prep HP
# 116. Moore HD
# 117. Oakwood School - North Hollywood KM
# 118. Bloomington HS South FB
# 119. Westlake WR
# 120. Nova SB
# 121. Park City OL
# 122. William Fremd GZ
# 123. Belvidere North MK
# 124. Rowland Hall AS
# 125. Chanhassen FC
# 126. Belvidere North KW
# 127. Brophy  SM
# 128. Miami Beach Sr GT
# 129. Denver East MN
# 130. Lake Highland Prep KB
# 131. Ardrey Kell DG
# 132. Madison West CR
# 133. John F. Kennedy EE
# 134. Nueva SS
# 135. Fargo Shanley WB
# 136. Pittsburgh Central Catholic EM
# 137. John F. Kennedy MR
# 138. Denver East GC
# 139. Park City GP
# 140. McDowell LD
# 141. McDowell BP
# 142. Cranbrook CR
# 143. Washburn Rural MM
# 144. Phoenix Country Day KM
# 145. Munster IK
# 146. NSU GM
# 147. Madison West PC
# 148. Mountain Brook JJ
# 149. Interlake HZ
# 150. Janesville Parker EE
# 151. Dowling Catholic HH
# 152. Miami Beach Sr AU
# 153. Madison West NC
# 154. Fishers RK
# 155. Desert Vista GK
# 156. Oakwood School - North Hollywood CS
# 157. Nova ES
# 158. Oxbridge Academy of the Palm Beaches SC
# 159. Oakwood School - North Hollywood MW
# 160. Seven Lakes IW
# 161. NSU RG
# 162. Oxbridge Academy of the Palm Beaches DH
# 163. Ransom Everglades RH
# 164. Oxbridge Academy of the Palm Beaches DF
# 165. James Madison Memorial GS
# 166. British International CO
# 167. Dowling Catholic HP
# 168. Cranbrook KL
# 169. Denver East BA
# 170. Phoenix Country Day MP
# 171. Phoenix Country Day MS
# 172. Fishers RC
# 173. North Broward Prep BC
# 174. James Logan TG
# 175. Denver East GM
# 176. Nova SS
# 177. Brentwood HS
# 178. Munster SB
# 179. Lincoln JJ
# 180. Brentwood LS
# 181. Munster CK
# 182. Oxbridge Academy of the Palm Beaches ShCo
# 183. Evanston Twp LK
# 184. West Des Moines Valley SJ
# 185. New Trier BO
# 186. Strake Jesuit  GW
